# %%
# !sudo apt install ruby-full
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-lato libgmp-dev libgmpxx4ldbl libruby3.0 rake ri ruby ruby-dev
#   ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0 ruby3.0-dev
#   ruby3.0-doc rubygems-integration
# Suggested packages:
#   gmp-doc libgmp10-doc libmpfr-dev bundler
# The following NEW packages will be installed:
#   fonts-lato libgmp-dev libgmpxx4ldbl libruby3.0 rake ri ruby ruby-dev
#   ruby-full ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   ruby3.0-dev ruby3.0-doc rubygems-integration
# 0 upgraded, 17 newly installed, 0 to remove and 41 not upgraded.
# Need to get 10.7 MB of archives.
# After this operation, 58.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-lato all 2.0-2.1 [2,696 kB]
# ...

# %%
# !ruby --version
# Out:
# ruby 3.0.2p107 (2021-07-07 revision 0db68f0233) [x86_64-linux-gnu]

# %%
# !gem install bitcoin-ruby
# Out:
# Fetching scrypt-3.1.0.gem
# Fetching eventmachine-1.2.7.gem
# Fetching rake-13.3.1.gem
# Fetching ffi-compiler-1.3.2.gem
# Fetching bitcoin-ruby-0.0.20.gem
# Fetching ffi-1.17.2.gem
# ...
# Building native extensions. This could take a while...
# ...
# Building native extensions. This could take a while...
# ...
# Building native extensions. This could take a while...
# ...
# Parsing documentation for rake-13.3.1
# Installing ri documentation for rake-13.3.1
# Parsing documentation for ffi-1.17.2
# Installing ri documentation for ffi-1.17.2
# Parsing documentation for ffi-compiler-1.3.2
# Installing ri documentation for ffi-compiler-1.3.2
# Parsing documentation for scrypt-3.1.0
# Installing ri documentation for scrypt-3.1.0
# Parsing documentation for eventmachine-1.2.7
# Installing ri documentation for eventmachine-1.2.7
# Parsing documentation for bitcoin-ruby-0.0.20
# Installing ri documentation for bitcoin-ruby-0.0.20
# ...

# %%
# !gem install ecdsa
# Out:
# Fetching ecdsa-1.2.0.gem
# ...
# Parsing documentation for ecdsa-1.2.0
# Installing ri documentation for ecdsa-1.2.0
# Done installing documentation for ecdsa after 0 seconds
# 1 gem installed

# %%
# !gem install base58
# Out:
# Fetching base58-0.2.3.gem
# ...
# Parsing documentation for base58-0.2.3
# Installing ri documentation for base58-0.2.3
# Done installing documentation for base58 after 0 seconds
# 1 gem installed

# %%
# !gem install crypto
# Out:
# Fetching crypto-0.0.3.gem
#
# ...
# Parsing documentation for crypto-0.0.3
# Installing ri documentation for crypto-0.0.3
# Done installing documentation for crypto after 0 seconds
# 1 gem installed

# %%
# !gem install config-hash -v 0.9.0
# Out:
# Fetching config-hash-0.9.0.gem
# ...
# Parsing documentation for config-hash-0.9.0
# Installing ri documentation for config-hash-0.9.0
# Done installing documentation for config-hash after 0 seconds
# 1 gem installed

# %%
# !git clone https://github.com/rapid7/metasploit-framework.git
# Out:
# Cloning into 'metasploit-framework'...
# remote: Enumerating objects: 736341, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 736341 (delta 57), reused 34 (delta 33), pack-reused 736254 (from 3)
# Receiving objects: 100% (736341/736341), 1.13 GiB | 26.06 MiB/s, done.
# Resolving deltas: 100% (549816/549816), done.
# Updating files: 100% (14042/14042), done.

# %%
ls
# Out:
# metasploit-framework/  sample_data/

# %%
cd metasploit-framework/
# Out:
# /content/metasploit-framework

# %%
ls
# Out:
# app/                         external/                     msfrpcd*
# CODE_OF_CONDUCT.md           Gemfile                       msfupdate*
# config/                      Gemfile.local.example         msfvenom*
# CONTRIBUTING.md              Gemfile.lock                  msf-ws.ru
# COPYING                      kubernetes/                   plugins/
# cortex.yaml                  lib/                          Rakefile*
# CURRENT.md                   LICENSE                       README.md
# data/                        LICENSE_GEMS                  script/
# db/                          metasploit-framework.gemspec  scripts/
# docker/                      modules/                      spec/
# docker-compose.override.yml  msfconsole*                   test/
# docker-compose.yml           msfd*                         tools/
# Dockerfile                   msfdb*                        Vagrantfile
# docs/                        msf-json-rpc.ru
# documentation/               msfrpc*

# %%
# !./msfvenom -help
# Out:
# MsfVenom - a Metasploit standalone payload generator.
# Also a replacement for msfpayload and msfencode.
# Usage: ./msfvenom [options] <var=val>
# Example: ./msfvenom -p windows/meterpreter/reverse_tcp LHOST=<IP> -f exe -o payload.exe
#
# Options:
#     -l, --list            <type>     List all modules for [type]. Types are: payloads, encoders, nops, platforms, archs, encrypt, formats, all
#     -p, --payload         <payload>  Payload to use (--list payloads to list, --list-options for arguments). Specify '-' or STDIN for custom
#         --list-options               List --payload <value>'s standard, advanced and evasion options
#     -f, --format          <format>   Output format (use --list formats to list)
#     -e, --encoder         <encoder>  The encoder to use (use --list encoders to list)
#         --service-name    <value>    The service name to use when generating a service binary
# ...

# %%
# !git clone https://github.com/bitcoin/bitcoin.git
# Out:
# Cloning into 'bitcoin'...
# remote: Enumerating objects: 317830, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 317830 (delta 145), reused 92 (delta 88), pack-reused 317621 (from 3)
# Receiving objects: 100% (317830/317830), 289.23 MiB | 20.69 MiB/s, done.
# Resolving deltas: 100% (229301/229301), done.

# %%
ls
# Out:
# app/                         documentation/                msfrpc*
# bitcoin/                     external/                     msfrpcd*
# CODE_OF_CONDUCT.md           Gemfile                       msfupdate*
# config/                      Gemfile.local.example         msfvenom*
# CONTRIBUTING.md              Gemfile.lock                  msf-ws.ru
# COPYING                      kubernetes/                   plugins/
# cortex.yaml                  lib/                          Rakefile*
# CURRENT.md                   LICENSE                       README.md
# data/                        LICENSE_GEMS                  script/
# db/                          metasploit-framework.gemspec  scripts/
# docker/                      modules/                      spec/
# docker-compose.override.yml  msfconsole*                   test/
# docker-compose.yml           msfd*                         tools/
# Dockerfile                   msfdb*                        Vagrantfile
# ...

# %%
cd bitcoin/src/crypto/
# Out:
# /content/metasploit-framework/bitcoin/src/crypto

# %%
ls
# Out:
# aes.cpp               hmac_sha256.cpp       sha256_avx2.cpp
# aes.h                 hmac_sha256.h         sha256.cpp
# chacha20.cpp          hmac_sha512.cpp       sha256.h
# chacha20.h            hmac_sha512.h         sha256_sse41.cpp
# chacha20poly1305.cpp  muhash.cpp            sha256_sse4.cpp
# chacha20poly1305.h    muhash.h              sha256_x86_shani.cpp
# CMakeLists.txt        poly1305.cpp          sha3.cpp
# common.h              poly1305.h            sha3.h
# ctaes/                ripemd160.cpp         sha512.cpp
# hex_base.cpp          ripemd160.h           sha512.h
# hex_base.h            sha1.cpp              siphash.cpp
# hkdf_sha256_32.cpp    sha1.h                siphash.h
# hkdf_sha256_32.h      sha256_arm_shani.cpp

# %%
cat aes.cpp
# Out:
# // Copyright (c) 2016-present The Bitcoin Core developers
# // Distributed under the MIT software license, see the accompanying
# // file COPYING or http://www.opensource.org/licenses/mit-license.php.
#
# #include <crypto/aes.h>
#
# #include <cstring>
#
# extern "C" {
# #include <crypto/ctaes/ctaes.c>
# }
#
# AES256Encrypt::AES256Encrypt(const unsigned char key[32])
# {
#     AES256_init(&ctx, key);
# }
#
# AES256Encrypt::~AES256Encrypt()
# {
#     memset(&ctx, 0, sizeof(ctx));
# }
#
# void AES256Encrypt::Encrypt(unsigned char ciphertext[16], const unsigned char plaintext[16]) const
# {
#     AES256_encrypt(&ctx, 1, ciphertext, plaintext);
# }
#
# AES256Decrypt::AES256Decrypt(const unsigned char key[32])
# {
#     AES256_init(&ctx, key);
# }
#
# AES256Decrypt::~AES256Decrypt()
# {
#     memset(&ctx, 0, sizeof(ctx));
# }
#
# void AES256Decrypt::Decrypt(unsigned char plaintext[16], const unsigned char ciphertext[16]) const
# {
#     AES256_decrypt(&ctx, 1, plaintext, ciphertext);
# }
# ...

# %%
! wget https://github.com/michaelcryptonl001-code/testlab/blob/1ad01880d00f39e73071d0f3bd32169629fb550e/test-wallet.dat
# Out:
# --2025-11-17 13:49:26--  https://github.com/michaelcryptonl001-code/testlab/blob/1ad01880d00f39e73071d0f3bd32169629fb550e/test-wallet.dat
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘test-wallet.dat’
#
# test-wallet.dat         [ <=>                ] 177.29K  --.-KB/s    in 0.05s
#
# 2025-11-17 13:49:26 (3.48 MB/s) - ‘test-wallet.dat’ saved [181541]

# %%
ls
# Out:
# aes.cpp               hmac_sha256.cpp       sha256_avx2.cpp
# aes.h                 hmac_sha256.h         sha256.cpp
# chacha20.cpp          hmac_sha512.cpp       sha256.h
# chacha20.h            hmac_sha512.h         sha256_sse41.cpp
# chacha20poly1305.cpp  muhash.cpp            sha256_sse4.cpp
# chacha20poly1305.h    muhash.h              sha256_x86_shani.cpp
# CMakeLists.txt        poly1305.cpp          sha3.cpp
# common.h              poly1305.h            sha3.h
# ctaes/                ripemd160.cpp         sha512.cpp
# hex_base.cpp          ripemd160.h           sha512.h
# hex_base.h            sha1.cpp              siphash.cpp
# hkdf_sha256_32.cpp    sha1.h                siphash.h
# hkdf_sha256_32.h      sha256_arm_shani.cpp  test-wallet.dat

# %%
cd /
# Out:
# /

# %%
cd content/metasploit-framework/
# Out:
# /content/metasploit-framework

# %%
ls
# Out:
# app/                         documentation/                msfrpc*
# bitcoin/                     external/                     msfrpcd*
# CODE_OF_CONDUCT.md           Gemfile                       msfupdate*
# config/                      Gemfile.local.example         msfvenom*
# CONTRIBUTING.md              Gemfile.lock                  msf-ws.ru
# COPYING                      kubernetes/                   plugins/
# cortex.yaml                  lib/                          Rakefile*
# CURRENT.md                   LICENSE                       README.md
# data/                        LICENSE_GEMS                  script/
# db/                          metasploit-framework.gemspec  scripts/
# docker/                      modules/                      spec/
# docker-compose.override.yml  msfconsole*                   test/
# docker-compose.yml           msfd*                         tools/
# Dockerfile                   msfdb*                        Vagrantfile
# ...

# %%
cd modules/
# Out:
# /content/metasploit-framework/modules

# %%
ls
# Out:
# auxiliary/  encoders/  evasion/  exploits/  nops/  payloads/  post/  README.md

# %%
cd exploits/
# Out:
# /content/metasploit-framework/modules/exploits

# %%
# !wget https://github.com/michaelcryptonl001-code/testlab/blob/d16498477079ace3ddd77622b01b5cbf8e6678b4/ExploitDarlenePRO.zip
# Out:
# --2025-11-17 14:50:30--  https://github.com/michaelcryptonl001-code/testlab/blob/d16498477079ace3ddd77622b01b5cbf8e6678b4/ExploitDarlenePRO.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘ExploitDarlenePRO.zip’
#
# ExploitDarlenePRO.z     [ <=>                ] 177.46K  --.-KB/s    in 0.04s
#
# 2025-11-17 14:50:30 (4.61 MB/s) - ‘ExploitDarlenePRO.zip’ saved [181714]

# %%
# !unzip ExploitDarlenePRO.zip
# Out:
# Archive:  ExploitDarlenePRO.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of ExploitDarlenePRO.zip or
#         ExploitDarlenePRO.zip.zip, and cannot find ExploitDarlenePRO.zip.ZIP, period.
